# %% [markdown]
# # Six Views of a Point Charge
#
# One of the challenges of electrodynamics is developing an intuition for potentials and fields.  What is a field?  What does it *look* like?
#
# We can answer the first question with a formal definition.  A ***field*** is a mathematical object that assigns a quantity to every point in space.  If the quantity is just a number, we call the object a ***scalar field***.  If the quantity is a vector, we call the object a ***vector field***.
#
# It is hard to say what a field "looks like".  What does temperature look like?  What does gravity look like?  Even if we can't see the quantity in question, we have many ways to represent it.  This problem will introduce you to some useful Python functions as we explore the potentials and electric fields of electric charges.

# %% [markdown]
# ## Point Charge
#
# The electrostatic potential of a point charge is
# $$V(\vec{r}) = \dfrac{kq}{r}$$
#
# The electric field of a point charge is
# $$\vec{E}(\vec{r}) = \dfrac{kq}{r^2} \hat{r}$$
#
# The following Python ***functions*** will compute the potential and electric field of a point charge.

# %%
# Get access to useful functions.
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
# Define functions to calculate fields.
def coordinates(charge=1, location=(0,0,0), box_size=5, grid_points=201, epsilon=1e-6):
    s = np.linspace(-box_size, box_size, grid_points)
    X,Y,Z = np.meshgrid(s,s,s, indexing='ij')
    
    return X, Y, Z

def potential(charge=1, location=(0,0,0), box_size=5, grid_points=201, epsilon=1e-6):
    x0, y0, z0 = location
    q = charge

    s = np.linspace(-box_size, box_size, grid_points)
    X,Y,Z = np.meshgrid(s,s,s, indexing='ij')
    R = np.sqrt((X-x0)**2 + (Y-y0)**2 + (Z-z0)**2 + epsilon**2)
    V = q/R
    
    return V

def field(charge=1, location=(0,0,0), box_size=5, grid_points=201, epsilon=1e-6):
    x0, y0, z0 = location
    q = charge

    s = np.linspace(-box_size, box_size, grid_points)
    X,Y,Z = np.meshgrid(s,s,s, indexing='ij')
    R = np.sqrt((X-x0)**2 + (Y-y0)**2 + (Z-z0)**2 + epsilon**2)
    Ex = q*(X-x0)/R**3
    Ey = q*(Y-y0)/R**3
    Ez = q*(Z-z0)/R**3
    
    return Ex, Ey, Ez

# %%
X, Y, Z = coordinates()
V = potential()
Ex, Ey, Ez = field()

# %% [markdown]
# Now that we have a scalar field and a vector field, let's look at them!

# %% [markdown]
# ### 1. 1D Slices of Potential
#
# The following code will plot the potential along three lines through a point you specify: one line parallel to the x-axis, one parallel to the y-axis, and one parallel to the z-axis.

# %%
# Choose coordinate indices for slices.
x0 = 50
y0 = 50
z0 = 150

x_val = X[x0,y0,z0]
y_val = Y[x0,y0,z0]
z_val = Z[x0,y0,z0]

print("The slices are taken through (x0,y0,z0) = (%g, %g, %g)." % (x_val, y_val, z_val))

# Create a figure and plot the slices.
fig, ax = plt.subplots(3, dpi=200)

# Plot V(x,y0,z0)
x = X[:,y0,z0]
v1 = V[:,y0,z0]
ax[0].plot(x,v1)
ax[0].set_title(r"$V(x,y_0,z_0)$")

# Plot V(x0,y,z0)
y = Y[x0,:,z0]
v2 = V[x0,:,z0]
ax[1].plot(y,v2)
ax[1].set_title(r"$V(x_0,y,z_0)$")

# Plot V(x0,y0,z)
z = Z[x0,y0,:]
v3 = V[x0,y0,:]
ax[2].plot(z,v3)
ax[2].set_title(r"$V(x_0,y_0,z)$")


fig.tight_layout()
# Out:
# The slices are taken through (x0,y0,z0) = (-2.5, -2.5, 2.5).

# %% [markdown]
# Change the values of `x0`, `y0`, and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the potential reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# This representation shows that, depending on the point in space you are measuring from, the distrubition of potential from a point charge can vary between axis.
# The potentials across each axis at x0 = y0 = z0 = 100 confirms the expected shape of 1/r, and the symmetry is maintained for initial points along constant radii, such as x0 = 50, y0 = 150, z0 = 50 and x0 = 50, y0 = 50, z0 = 150.
# However, due to the constraint of being a measurment across 1D lines, the 2D and 3D field is not trivial to visualize.

# %% [markdown]
# ### 2. 2D Slices of Potential
#
# The cell below will plot a 2D slice of the potential through a height that you specify.
#
# It will display a surface plot and a heatmap.

# %%
# Choose z-coordinate index for slices.
z0 = 100
z_val = Z[x0,y0,z0]

print("The slice is taken through z0 = %g." % z_val)

# Get slice
x = X[:,:,z0]
y = Y[:,:,z0]
v = V[:,:,z0]

# Create a surface plot.
fig = plt.figure(dpi=200)
ax1 = fig.add_subplot(projection='3d')
ax1.plot_surface(x,y,v, cmap='jet', antialiased=False, linewidth=0)
ax1.set_title(r"$V(x,y,z_0)$")

# Heatmap
fig, ax2 = plt.subplots(dpi=200)
image = ax2.pcolormesh(x,y,v, shading='gouraud', cmap='jet')
plt.colorbar(image, use_gridspec=True)
ax2.axis('scaled')
# Out:
# The slice is taken through z0 = 0.
# (-5.0, 5.0, -5.0, 5.0)

# %% [markdown]
# Change the value of `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the potential reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# This 2D plot reveals the full symmetry of the field (especially at z0 = 100) as we look at different X-Y slices.
# While this visualization does not change the values for the data displayed (compared to the first visualization), there is an additional dimentions' worth of it at a time. The 2D plot also allows for the visual prediction of the X and Y axis behavior of a charged particle somewhere in the X-Y plane at z = z0.
# While there is a considerable increase in the amount of conveyed information per excution, this particualr implementation is still limited to a single slice of the 3D space at a time.

# %% [markdown]
# ### 3. 1D Slices of Electric Field
#
# The following code will plot the components of the electric field along three lines through a point you specify: one line parallel to the x-axis, one parallel to the y-axis, and one parallel to the z-axis.

# %%
# Choose coordinate indices for slices.
x0 = 100
y0 = 100
z0 = 85

x_val = X[x0,y0,z0]
y_val = Y[x0,y0,z0]
z_val = Z[x0,y0,z0]

print("The slices are taken through (x0,y0,z0) = (%g, %g, %g)." % (x_val, y_val, z_val))

# Create a figure and plot the slices.
fig, ax = plt.subplots(3,3, dpi=200)

# Plot components of E(x,y0,z0)
x = X[:,y0,z0]
y = Y[x0,:,z0]
z = Z[x0,y0,:]


Ex1 = Ex[:,y0,z0]
ax[0,0].plot(x,Ex1)
ax[0,0].set_ylabel(r"$E_x$")

Ey1 = Ey[:,y0,z0]
ax[1,0].plot(x,Ey1)
ax[1,0].set_ylabel(r"$E_y$")

Ez1 = Ez[:,y0,z0]
ax[2,0].plot(x,Ez1)
ax[2,0].set_ylabel(r"$E_z$")
ax[2,0].set_xlabel('x')


Ex2 = Ex[x0,:,z0]
ax[0,1].plot(y,Ex2)

Ey2 = Ey[x0,:,z0]
ax[1,1].plot(y,Ey2)

Ez2 = Ez[x0,:,z0]
ax[2,1].plot(y,Ez2)
ax[2,1].set_xlabel('y')


Ex3 = Ex[x0,y0,:]
ax[0,2].plot(z,Ex3)

Ey3 = Ey[x0,y0,:]
ax[1,2].plot(z,Ey3)

Ez3 = Ez[x0,y0,:] # Noticed an asymmetry on this line causing odd behavior, unified and got more expected results
ax[2,2].plot(z,Ez3)
ax[2,2].set_xlabel('z')

fig.tight_layout()
# Out:
# The slices are taken through (x0,y0,z0) = (0, 0, -0.75).

# %% [markdown]
# Change the values of `x0`, `y0`, and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# In this set of field graphs, unlike the in potential graphs, the sign (and therefore directionality of force) of the field components changes depending on which 'side' of the point chrage you (a positive test charge) are on.
# It seems at when any axis passes through the point charge, the change in field strength of that axis' component is completely constrained to itself (no other axis components change in the sweep across its own axis).
# Due to the relatively low computational resolution of this simulation, the discontinuities when crossing directly "across" the point charge are not perfectly recreated.

# %% [markdown]
# ### 4. 2D Slices of Electric Field
#
# The cell below will plot a 2D slice of the components of the electric field through a height that you specify.
#
# It will display a surface plot and a heatmap of each component.

# %%
# Choose z-coordinate index for slices.
z0 = 85
z_val = Z[x0,y0,z0]

print("The slice is taken through z0 = %g." % z_val)

# Get slices
x = X[:,:,z0]
y = Y[:,:,z0]
ex = Ex[:,:,z0]
ey = Ey[:,:,z0]
ez = Ez[:,:,z0]

# Create a surface plots.
fig = plt.figure(dpi=200)

ax = fig.add_subplot(2,3,1, projection='3d')
ax.plot_surface(x,y,ex, cmap='jet', antialiased=False, linewidth=0)
ax.set_title(r"$E_x(x,y,z_0)$")

ax = fig.add_subplot(2,3,2, projection='3d')
ax.plot_surface(x,y,ey, cmap='jet', antialiased=False, linewidth=0)
ax.set_title(r"$E_y(x,y,z_0)$")

ax = fig.add_subplot(2,3,3, projection='3d')
ax.plot_surface(x,y,ez, cmap='jet', antialiased=False, linewidth=0)
ax.set_title(r"$E_z(x,y,z_0)$")

# Heatmaps
ax = fig.add_subplot(2,3,4)
image = ax.pcolormesh(x,y,ex, shading='gouraud', cmap='jet')
ax.axis('scaled')

ax = fig.add_subplot(2,3,5)
image = ax.pcolormesh(x,y,ey, shading='gouraud', cmap='jet')
ax.axis('scaled')

ax = fig.add_subplot(2,3,6)
image = ax.pcolormesh(x,y,ez, shading='gouraud', cmap='jet')
ax.axis('scaled')

fig.tight_layout()

# image = ax.pcolormesh(x,y,v, shading='gouraud', cmap='jet')
# plt.colorbar(image, use_gridspec=True)
# ax.axis('scaled')
# Out:
# The slice is taken through z0 = -0.75.

# %% [markdown]
# Change the value of `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# The same observations from the previous 2D visualization apply; the symmetry of the field is clear - although the x and y components don't look as symmetrical since they are being viewed off-axis.
# However, this off-axis view provides another look into the directionality of the fields in the x and y axes.
# Dispite this useful look into the individual components of the field, this view can be a bit misleading, as the negative values may lead some to beleive that this would cause an attraction of a positive test charge, when in fact the sign is just a result of the particular coordinate system used.

# %% [markdown]
# ### 5. Quiver Plots of Electric Field
#
# The cell below will create a 3D "quiver plot" of the electric field and a 2D quiver plot of a slice through the electric field.

# %%
# Uncomment the last line for interactive plots.

# %matplotlib inline
# %matplotlib notebook

# %%
# Create a quiver plot.
# Use a coarser grid.
stride = 40
x = X[::stride,::stride,::stride].copy()
y = Y[::stride,::stride,::stride].copy()
z = Z[::stride,::stride,::stride].copy()
ex = Ex[::stride,::stride,::stride].copy()
ey = Ey[::stride,::stride,::stride].copy()
ez = Ez[::stride,::stride,::stride].copy()

# Set max length to improve visibility in plot.
ecut = 0.5
ex[ex>ecut] = ecut
ey[ey>ecut] = ecut
ez[ez>ecut] = ecut
ex[ex<-ecut] = -ecut
ey[ey<-ecut] = -ecut
ez[ez<-ecut] = -ecut

fig = plt.figure(dpi=200)
ax = fig.add_subplot(projection='3d')
ax.quiver3D(x,y,z,ex,ey,ez, pivot='middle', length=5, linewidth=0.5, color='red')
ax.set_title(r"$\vec{E}(\vec{R})$")

# Make a 2D plot of a slice of the field.
z0 = 58
z_val = Z[0,0,z0]

# Use a coarser grid.
stride = 25
x = X[::stride,::stride,z0].copy()
y = Y[::stride,::stride,z0].copy()
ex = Ex[::stride,::stride,z0].copy()
ey = Ey[::stride,::stride,z0].copy()

# Set max length to improve visibility in plot.
ex[ex>ecut] = ecut
ey[ey>ecut] = ecut
ex[ex<-ecut] = -ecut
ey[ey<-ecut] = -ecut

fig = plt.figure(dpi=200)
ax = fig.add_subplot()
ax.quiver(x,y,ex,ey, pivot='middle', scale=0.8, linewidth=0.5, color='red')
ax.set_title("Projection of field onto plane at z=%g" % z_val)
ax.axis("scaled")
# Out:
# (-5.5, 5.5, -5.5, 5.5)

# %% [markdown]
# Change the values of `ecut` and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# I personally quite like this visualization. It clearly indicates the magnitude and direction of the field in 3D via isometric vector field projection, and can be 'sliced' to get 2D vector field views (byproduct of the 3D plot?).
# Of course, with a 3D projection onto a 2D plane (a monitor in this case), there will be some information density limitations. in order not to obscure the vectors in the 'rear' of the 3D plot, thir number, size, and length must be handled carefully, and the viewing angle must be adjusted as well. Multiple views or rotatable figures can midigate this to an extent.

# %% [markdown]
# ### 6. Streamlines of the Electric Field
#
# The cell below will draw three dimensional "field lines" of the electric field.

# %%
# Make a 2D plot of a slice of the field.
z0 = 100
z_val = Z[0,0,z0]

# Use a coarser grid.
stride = 1
x = X[::stride,::stride,z0].copy().T
y = Y[::stride,::stride,z0].copy().T
ex = Ex[::stride,::stride,z0].copy().T
ey = Ey[::stride,::stride,z0].copy().T

# Set max length to improve visibility in plot.
ecut = 0.5
ex[ex>ecut] = ecut
ey[ey>ecut] = ecut
ex[ex<-ecut] = -ecut
ey[ey<-ecut] = -ecut

fig = plt.figure(dpi=200)
ax = fig.add_subplot()
ax.streamplot(x,y,ex,ey, linewidth=0.5, density=1.5)
ax.set_title("Projection of field onto plane at z=%g" % z_val)
ax.axis("scaled")
# Out:
# (-5.0, 5.0, -5.0, 5.0)

# %% [markdown]
# Change the values of `ecut` and `z0` in the cell above and run it again.  Do this several times.
#
# What does this representation of the electric field reveal?  What information does it provide?  What are its limitations?
#
# ***Type your response in the box below.***

# %% [markdown]
# This visualization certainly reminds you that the field lines originate and terminate in charges. In this case, since all lines are leaving the point charge, we know that it has a positive charge.
# I'm not really sure why, but around z0 = 100, the field lines appear to be chaotic and asymmetrical. I assume this is an issue with the computational resolution. It is, however, a good reminder that field lines cannot cross each other.

# %% [markdown]
# ## Reflection
#
# All of these plots are representations of the same underlying physical entity: the electromagnetic field of a single point charge.  Which did you find most useful?  Confusing?  Can you think of another way to represent a three-dimensional electric field or scalar field?
#
# ***Type your response in the box below.***

# %% [markdown]
# I personally found the 3D quiver plot to be the most useful since it conveys the most information in a single figure. In the opposite vein, I did not like the field line viewer in this exercise, as the system of only one object (the point charge) makes all slices very similar - and there even seems to be artifacting in it!
# I would like to see a color-transparency graded 3D plot of the potential field. I think it would be neat.
